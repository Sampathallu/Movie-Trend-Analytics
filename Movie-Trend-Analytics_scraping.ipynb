# %%
from bs4 import BeautifulSoup
import requests
import urllib.request 
import pandas as pd
import numpy as np
import re
import time

# %%
movies_2018 = pd.DataFrame()
start = 1 
moviename = list()
genre = list()
grossmov = list()
duration = list()
imdbrating = list()
metarating = list()
votes = list()
directormov = list()
starcast = list()

# %%
for length in range(1,3):
    if (length == 1):
        start = 1
    else:
        start = start + 50

    url_2018 = 'https://www.imdb.com/search/title?title_type=feature&year=2018-01-01,2018-12-31&start='+ str(start) +'&ref_=adv_nxt'
    request = requests.get(url_2018)
    soup = BeautifulSoup(request.content, 'html.parser')
   
    namecontent = soup.find_all('h3', {"class" : 'lister-item-header'})
    for i in namecontent:
    # namecontent = soup.find('h3', {"class" : 'lister-item-header'})
        moviename.append(i.text.strip())
    genrecontent = soup.find_all('span', {"class" : 'genre'})
    for i in genrecontent:
        genre.append(i.text.strip())
    imdbratingcontent = soup.find_all('div', {"class" : 'inline-block ratings-imdb-rating'})
    for i in imdbratingcontent:
        imdbrating.append(i.text.strip())
    divs = soup.findAll('div', {'class':'lister-item'})
    for div in divs:
        spans = div.findAll('span', {'name':'nv'})
        vote = spans[0]['data-value']
        votes.append(vote)
        try:
            gross = spans[1]['data-value']       
        except:
            gross = ""
        grossmov.append(gross)
    durationcontent = soup.find_all('span', {"class" : 'runtime'})
    for i in durationcontent:
        duration.append(i.text.strip())
    ratingsbar = soup.find_all('div', {"class" : 'ratings-bar'})
    for ir in ratingsbar:
        if ir.find_all('div', {"class" : 'inline-block ratings-metascore'}):
            metacontent = ir.find_all('div', {"class" : 'inline-block ratings-metascore'})
            for i in metacontent:
                if (i.find_all('span', {"class" : 'metascore favorable'})):
                    metarating.append(i.text.strip())
                if (i.find_all('span', {"class" : 'metascore mixed'})):
                    metarating.append(i.text.strip())
                if (i.find_all('span', {"class" : 'metascore unfavorable'})):
                    metarating.append(i.text.strip())
        else:
            metarating.append("")
    count = 0
    for directors in soup.find_all(href=re.compile("adv_li_dr")):
        if (bool(re.search('adv_li_dr_0', str(directors))) == 1):
            directormov.append(directors.next_element)
            count = count + 1
        if (bool(re.search('adv_li_dr_1', str(directors))) == 1):
            directormov[count-1] = directormov[count-1] + "," + directors.next_element
    string = ""
    for idx, actors in enumerate(soup.find_all(href=re.compile("adv_li_st"))):
        if (bool(re.search('adv_li_st_0', str(actors))) == 1):
            string = string + actors.next_element
        if (bool(re.search('adv_li_st_1', str(actors))) == 1):
            string = string + "," + str(actors.next_element)
#         if (bool(re.search('adv_li_st_2', str(actors))) == 1):
#             string = string + "," + str(actors.next_element)
            starcast.append(string)
            string = ""
  
   
    time.sleep(5)

# %%
print(len(moviename))
print(len(genre))
print(len(grossmov))
print(len(duration))
print(len(imdbrating))
print(len(metarating))
print(len(votes))
print(len(directormov))
print(len(starcast))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
movies_2018['moviename'] = moviename
movies_2018['genre'] = genre
movies_2018['imdbrating'] = imdbrating
movies_2018['votes'] = votes
movies_2018['grossmov'] = grossmov
movies_2018['duration'] = duration
movies_2018['metarating'] = metarating
movies_2018['directormov'] = directormov
movies_2018['starcast'] = starcast

# %%
movies_2018
# Out:
#                                             moviename  \
# 0                                 1.\nAquaman\n(2018)
# 1                              2.\nGreen Book\n(2018)
# 2                       3.\nBohemian Rhapsody\n(2018)
# 3       4.\nSpider-Man: Into the Spider-Verse\n(2018)
# 4                  5.\nAvengers: Infinity War\n(2018)
# 5                          6.\nA Star Is Born\n(2018)
# 6                           7.\nThe Favourite\n(2018)
# 7   8.\nFantastic Beasts: The Crimes of Grindelwal...
# 8                    9.\nMary Poppins Returns\n(2018)
# 9                         10.\nInstant Family\n(2018)
# 10                           11.\nA.I. Rising\n(2018)
# 11        12.\nJurassic World: Fallen Kingdom\n(2018)
# 12                              13.\nVice\n(I) (2018)
# 13                        14.\nMortal Engines\n(2018)
# 14                              15.\nCreed II\n(2018)
# 15                     16.\nChristopher Robin\n(2018)
# 16                       17.\nHolmes & Watson\n(2018)
# 17                         18.\nBlack Panther\n(2018)
# 18                                 19.\nKursk\n(2018)
# 19             20.\nRalph Breaks the Internet\n(2018)
# 20                            21.\nDeadpool 2\n(2018)
# 21                        22.\nBlacKkKlansman\n(2018)
# 22                              23.\nOverlord\n(2018)
# 23                   24.\nMary Queen of Scots\n(2018)
# 24                                 25.\nGreta\n(2018)
# 25                                  26.\nRoma\n(2018)
# 26                        27.\nRobin Hood\n(I) (2018)
# 27                                28.\nWidows\n(2018)
# 28                            29.\nClimax\n(I) (2018)
# 29                            30.\nHereditary\n(2018)
# ..                                                ...
# 70                 71.\nUnder the Silver Lake\n(2018)
# 71                                72.\nBorder\n(2018)
# 72                               73.\nBurning\n(2018)
# 73                     74.\nBeautiful Boy\n(I) (2018)
# 74                                75.\nArctic\n(2018)
# 75           76.\nSicario: Day of the Soldado\n(2018)
# 76           77.\nMamma Mia! Here We Go Again\n(2018)
# 77                  78.\nThe Sisters Brothers\n(2018)
# 78                            79.\nSecond Act\n(2018)
# 79                              80.\nProspect\n(2018)
# 80                             81.\nGirl\n(II) (2018)
# 81                              82.\nCold War\n(2018)
# 82                              83.\nWildlife\n(2018)
# 83                          84.\nThe Predator\n(2018)
# 84                               85.\nThe Meg\n(2018)
# 85                               86.\nTag\n(I) (2018)
# 86                         87.\nThe Vanishing\n(2018)
# 87                           88.\nRed Sparrow\n(2018)
# 88        89.\nThe Possession of Hannah Grace\n(2018)
# 89                             90.\nHigh Life\n(2018)
# 90               91.\nDragged Across Concrete\n(2018)
# 91                         92.\nI Feel Pretty\n(2018)
# 92                               93.\nUpgrade\n(2018)
# 93                        94.\nDen of Thieves\n(2018)
# 94                           95.\nGloria Bell\n(2018)
# 95                        96.\nGame Night\n(I) (2018)
# 96        97.\nThe Man Who Killed Don Quixote\n(2018)
# 97                            98.\nThe Guilty\n(2018)
# 98                       99.\nSearching\n(III) (2018)
# 99                100.\nLife of the Party\n(I) (2018)
#
#                            genre imdbrating   votes     grossmov duration  \
# 0     Action, Adventure, Fantasy        7.2  205203  334,548,294  143 min
# 1       Biography, Comedy, Drama        8.3  151806   83,279,956  130 min
# 2        Biography, Drama, Music        8.1  306473  215,797,214  134 min
# 91               Comedy, Romance        5.4   36891   48,795,601  110 min
# 92      Action, Sci-Fi, Thriller        7.6   95950   11,871,365  100 min
# 93          Action, Crime, Drama        7.0   66172   44,947,622  140 min
# 94        Comedy, Drama, Romance        6.8     638      695,985  102 min
# 95         Action, Comedy, Crime        7.0  154337   69,001,013  100 min
# 96      Adventure, Comedy, Drama        6.5    6128               132 min
# 97        Crime, Drama, Thriller        7.5   20911      207,140   85 min
# 98      Drama, Mystery, Thriller        7.7   86112   26,020,957  102 min
# 99                        Comedy        5.5   23840   52,856,061  105 min
#
#                        metarating                   directormov  \
# 0   55        \n        Metascore                     James Wan
# 1   69        \n        Metascore                Peter Farrelly
# 2   49        \n        Metascore                  Bryan Singer
# 3   87        \n        Metascore  Bob Persichetti,Peter Ramsey
# 4   68        \n        Metascore       Anthony Russo,Joe Russo
# 5   88        \n        Metascore                Bradley Cooper
# 6   90        \n        Metascore              Yorgos Lanthimos
# 7   52        \n        Metascore                   David Yates
# 8   66        \n        Metascore                  Rob Marshall
# 9   57        \n        Metascore                   Sean Anders
# 10                                                Lazar Bodroza
# 11  51        \n        Metascore                   J.A. Bayona
# 12  61        \n        Metascore                    Adam McKay
# 13  44        \n        Metascore              Christian Rivers
# 14  66        \n        Metascore              Steven Caple Jr.
# 15  60        \n        Metascore                  Marc Forster
# 16  24        \n        Metascore                    Etan Cohen
# 17  88        \n        Metascore                  Ryan Coogler
# 18  53        \n        Metascore             Thomas Vinterberg
# 19  71        \n        Metascore      Phil Johnston,Rich Moore
# 20  66        \n        Metascore                  David Leitch
# 21  83        \n        Metascore                     Spike Lee
# 22  60        \n        Metascore                  Julius Avery
# 23  60        \n        Metascore                  Josie Rourke
# 24  53        \n        Metascore                   Neil Jordan
# 25  96        \n        Metascore                Alfonso Cuarón
# 26  32        \n        Metascore                 Otto Bathurst
# 27  84        \n        Metascore                 Steve McQueen
# 28  67        \n        Metascore                    Gaspar Noé
# 29  87        \n        Metascore           Ari Aster,Zeek Earl
# ..                            ...                           ...
# 70  61        \n        Metascore         David Robert Mitchell
# 71  75        \n        Metascore                    Ali Abbasi
# 72  90        \n        Metascore                Chang-dong Lee
# 73  62        \n        Metascore          Felix van Groeningen
# 74  71        \n        Metascore                     Joe Penna
# 75  61        \n        Metascore               Stefano Sollima
# 76  60        \n        Metascore                     Ol Parker
# 77  78        \n        Metascore               Jacques Audiard
# 78  46        \n        Metascore                   Peter Segal
# 79  68        \n        Metascore          Christopher Caldwell
# 80  73        \n        Metascore                   Lukas Dhont
# 81  90        \n        Metascore             Pawel Pawlikowski
# 82  80        \n        Metascore                     Paul Dano
# 83  48        \n        Metascore                   Shane Black
# 84  46        \n        Metascore                Jon Turteltaub
# 85  56        \n        Metascore                   Jeff Tomsic
# 86  66        \n        Metascore             Kristoffer Nyholm
# 87  53        \n        Metascore              Francis Lawrence
# 88  37        \n        Metascore          Diederik Van Rooijen
# 89  81        \n        Metascore                  Claire Denis
# 90  63        \n        Metascore               S. Craig Zahler
# 91  48        \n        Metascore                     Abby Kohn
# 92  67        \n        Metascore                Leigh Whannell
# 93  49        \n        Metascore            Christian Gudegast
# 94  80        \n        Metascore               Sebastián Lelio
# 95  66        \n        Metascore            John Francis Daley
# 96  56        \n        Metascore                 Terry Gilliam
# 97  83        \n        Metascore                 Gustav Möller
# 98  71        \n        Metascore               Aneesh Chaganty
# 99  46        \n        Metascore                   Ben Falcone
#
#                                    starcast
# 0                   Jason Momoa,Amber Heard
# 1            Viggo Mortensen,Mahershala Ali
# 2                   Rami Malek,Lucy Boynton
# 3                Shameik Moore,Jake Johnson
# 4         Robert Downey Jr.,Chris Hemsworth
# 5                  Lady Gaga,Bradley Cooper
# 6                  Olivia Colman,Emma Stone
# 7        Eddie Redmayne,Katherine Waterston
# 8            Emily Blunt,Lin-Manuel Miranda
# 9                  Mark Wahlberg,Rose Byrne
# 10                  Sebastian Cavazza,Stoya
# 11          Chris Pratt,Bryce Dallas Howard
# 12                 Christian Bale,Amy Adams
# 13               Hera Hilmar,Robert Sheehan
# 14     Michael B. Jordan,Sylvester Stallone
# 15              Ewan McGregor,Hayley Atwell
# 16              Will Ferrell,John C. Reilly
# 17       Chadwick Boseman,Michael B. Jordan
# 18         Léa Seydoux,Matthias Schoenaerts
# 19           John C. Reilly,Sarah Silverman
# 20                Ryan Reynolds,Josh Brolin
# 21        John David Washington,Adam Driver
# 22                Jovan Adepo,Wyatt Russell
# 23              Saoirse Ronan,Margot Robbie
# 24      Isabelle Huppert,Chloë Grace Moretz
# 25        Yalitza Aparicio,Marina de Tavira
# 26                 Taron Egerton,Jamie Foxx
# 27           Viola Davis,Michelle Rodriguez
# 28         Sofia Boutella,Romain Guillermic
# 29              Toni Collette,Milly Shapiro
# ..                                      ...
# 70             Andrew Garfield,Riley Keough
# 71               Eva Melander,Eero Milonoff
# 72                    Ah-in Yoo,Steven Yeun
# 73               Steve Carell,Maura Tierney
# 74  Mads Mikkelsen,Maria Thelma Smáradóttir
# 75             Benicio Del Toro,Josh Brolin
# 76               Lily James,Amanda Seyfried
# 77           John C. Reilly,Joaquin Phoenix
# 78           Jennifer Lopez,Vanessa Hudgens
# 79              Sophie Thatcher,Jay Duplass
# 80          Victor Polster,Arieh Worthalter
# 81                  Joanna Kulig,Tomasz Kot
# 82             Ed Oxenbould,Jake Gyllenhaal
# 83            Boyd Holbrook,Trevante Rhodes
# 84                Jason Statham,Bingbing Li
# 85                   Jeremy Renner,Ed Helms
# 86               Gerard Butler,Peter Mullan
# 87          Jennifer Lawrence,Joel Edgerton
# 88                 Shay Mitchell,Grey Damon
# 89        Robert Pattinson,Juliette Binoche
# 90            Jennifer Carpenter,Mel Gibson
# 91            Amy Schumer,Michelle Williams
# 92     Logan Marshall-Green,Melanie Vallejo
# 93            Gerard Butler,Pablo Schreiber
# 94              Julianne Moore,Alanna Ubach
# 95             Jason Bateman,Rachel McAdams
# 96         José Luis Ferrer,Ismael Fritschi
# 97          Jakob Cedergren,Jessica Dinnage
# 98                   John Cho,Debra Messing
# 99              Melissa McCarthy,Matt Walsh
#
# [100 rows x 9 columns]
